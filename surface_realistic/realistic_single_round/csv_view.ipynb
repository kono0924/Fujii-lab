# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import os

################ 要変更 #################

# FUjii-labのパス
path = "/Users/konohideki/Documents/Fujii-lab/surface_realistic/realistic_single_round/d1=3,p=0.0001,eta=1000"

# ファイル名
file1 = "Z,p=0.0001,d2=(3,9,2),eta=1000,trials=20000" + ".csv"
file2 = "X,p=0.0001,d2=(3,9,2),eta=1000,trials=20000" + ".csv"
########################################

# csvファイルの読み込み
os.chdir(path)
data1 = pd.read_csv(file1, index_col=0)
data2 = pd.read_csv(file2, index_col=0)

# データフレームの行名(リスト)を取得
code_distance_list = data1.index

# データフレームの列名(リスト)を取得
round_list = data1.columns

##### グラフ作成 #####

a = np.array(round_list)
a = [float(num) for num in a]
a = np.array(a)

fig, axes = plt.subplots(1,3,figsize=(18,6))
for i in range(len(code_distance_list)):
    b = np.array(data1.loc[code_distance_list[i]])
    axes[0].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[1].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
axes[0].set_xlabel("round", fontsize=13)
axes[0].set_ylabel("logical failure probability", fontsize=13)
axes[0].set_ylim(0,)
axes[1].set_xlabel("round", fontsize=13)
axes[1].set_ylabel("logical failure probability", fontsize=13)
axes[2].set_xlabel("round", fontsize=13)
axes[2].set_ylabel("N2/p_X^L", fontsize=13)
# axes.spines["top"].set_linewidth(2)
# axes.spines["left"].set_linewidth(2)
# axes.spines["bottom"].set_linewidth(2)
# axes.spines["right"].set_linewidth(2)
axes[0].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[0].set_title("X error", fontsize=14)
axes[1].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[1].set_title("X error(log-log)", fontsize=14)
axes[1].set_xscale("log")
axes[1].set_yscale("log")
axes[2].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[2].set_title("X lifetime", fontsize=14)
plt.legend()
plt.show()


fig, axes = plt.subplots(1,3,figsize=(18,6))
for i in range(len(code_distance_list)):
    b = np.array(data2.loc[code_distance_list[i]])
    axes[0].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[1].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
axes[0].set_xlabel("round", fontsize=13)
axes[0].set_ylabel("logical failure probability", fontsize=13)
axes[0].set_ylim(0,)
axes[1].set_xlabel("round", fontsize=13)
axes[1].set_ylabel("logical failure probability", fontsize=13)
axes[2].set_xlabel("round", fontsize=13)
axes[2].set_ylabel("N2/p_Z^L", fontsize=13)
# axes.spines["top"].set_linewidth(2)
# axes.spines["left"].set_linewidth(2)
# axes.spines["bottom"].set_linewidth(2)
# axes.spines["right"].set_linewidth(2)
axes[0].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[0].set_title("Z error", fontsize=14)
axes[1].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[1].set_title("Z error(log-log)", fontsize=14)
axes[1].set_xscale("log")
axes[1].set_yscale("log")
axes[2].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[2].set_title("Z lifetime", fontsize=14)
plt.legend()
plt.show()
# Out:
# /var/folders/z2/d7v_26mx7_s1sc2tvt5zxxmc0000gn/T/ipykernel_80889/840236246.py:40: RuntimeWarning: divide by zero encountered in true_divide
#   axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import os

################ 要変更 #################

# FUjii-labのパス
path = "/Users/konohideki/Documents/Fujii-lab/surface_realistic/realistic_single_round/test,d1=7,p=0.0001,eta=1000"

# ファイル名
file1 = "X error,p=0.0001,d2=(3,9,2),eta=1000,trials=10000,ver0" + ".csv"
file2 = "Z error,p=0.0001,d2=(3,9,2),eta=1000,trials=10000,ver0" + ".csv"
########################################

# csvファイルの読み込み
os.chdir(path)
data1 = pd.read_csv(file1, index_col=0)
data2 = pd.read_csv(file2, index_col=0)

# データフレームの行名(リスト)を取得
code_distance_list = data1.index

# データフレームの列名(リスト)を取得
round_list = data1.columns

##### グラフ作成 #####

a = np.array(round_list)
a = [float(num) for num in a]
a = np.array(a)

fig, axes = plt.subplots(1,3,figsize=(18,6))
for i in range(len(code_distance_list)):
    b = np.array(data1.loc[code_distance_list[i]])
    axes[0].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[1].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
axes[0].set_xlabel("round", fontsize=13)
axes[0].set_ylabel("logical failure probability", fontsize=13)
axes[0].set_ylim(0,)
axes[1].set_xlabel("round", fontsize=13)
axes[1].set_ylabel("logical failure probability", fontsize=13)
axes[2].set_xlabel("round", fontsize=13)
axes[2].set_ylabel("N2/p_X^L", fontsize=13)
# axes.spines["top"].set_linewidth(2)
# axes.spines["left"].set_linewidth(2)
# axes.spines["bottom"].set_linewidth(2)
# axes.spines["right"].set_linewidth(2)
axes[0].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[0].set_title("X error", fontsize=14)
axes[1].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[1].set_title("X error(log-log)", fontsize=14)
axes[1].set_xscale("log")
axes[1].set_yscale("log")
axes[2].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[2].set_title("X lifetime", fontsize=14)
plt.legend()
plt.show()


fig, axes = plt.subplots(1,3,figsize=(18,6))
for i in range(len(code_distance_list)):
    b = np.array(data2.loc[code_distance_list[i]])
    axes[0].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[1].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
axes[0].set_xlabel("round", fontsize=13)
axes[0].set_ylabel("logical failure probability", fontsize=13)
axes[0].set_ylim(0,)
axes[1].set_xlabel("round", fontsize=13)
axes[1].set_ylabel("logical failure probability", fontsize=13)
axes[2].set_xlabel("round", fontsize=13)
axes[2].set_ylabel("N2/p_Z^L", fontsize=13)
# axes.spines["top"].set_linewidth(2)
# axes.spines["left"].set_linewidth(2)
# axes.spines["bottom"].set_linewidth(2)
# axes.spines["right"].set_linewidth(2)
axes[0].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[0].set_title("Z error", fontsize=14)
axes[1].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[1].set_title("Z error(log-log)", fontsize=14)
axes[1].set_xscale("log")
axes[1].set_yscale("log")
axes[2].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[2].set_title("Z lifetime", fontsize=14)
plt.legend()
plt.show()
# Out:
# /var/folders/z2/d7v_26mx7_s1sc2tvt5zxxmc0000gn/T/ipykernel_80889/3640332602.py:40: RuntimeWarning: divide by zero encountered in true_divide
#   axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
# /var/folders/z2/d7v_26mx7_s1sc2tvt5zxxmc0000gn/T/ipykernel_80889/3640332602.py:69: RuntimeWarning: divide by zero encountered in true_divide
#   axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
# /var/folders/z2/d7v_26mx7_s1sc2tvt5zxxmc0000gn/T/ipykernel_80889/3640332602.py:69: RuntimeWarning: divide by zero encountered in true_divide
#   axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
# /var/folders/z2/d7v_26mx7_s1sc2tvt5zxxmc0000gn/T/ipykernel_80889/3640332602.py:69: RuntimeWarning: divide by zero encountered in true_divide
#   axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import os

################ 要変更 #################

# FUjii-labのパス
path = "/Users/konohideki/Documents/Fujii-lab/surface_realistic/realistic_single_round/test,d1=5,p=5e-05,eta=1000"

# ファイル名
file1 = "X error,p=5e-05,d2=(3,9,2),eta=1000,trials=10000,ver0" + ".csv"
file2 = "Z error,p=5e-05,d2=(3,9,2),eta=1000,trials=10000,ver0" + ".csv"
########################################

# csvファイルの読み込み
os.chdir(path)
data1 = pd.read_csv(file1, index_col=0)
data2 = pd.read_csv(file2, index_col=0)

# データフレームの行名(リスト)を取得
code_distance_list = data1.index

# データフレームの列名(リスト)を取得
round_list = data1.columns

##### グラフ作成 #####

a = np.array(round_list)
a = [float(num) for num in a]
a = np.array(a)

fig, axes = plt.subplots(1,3,figsize=(18,6))
for i in range(len(code_distance_list)):
    b = np.array(data1.loc[code_distance_list[i]])
    axes[0].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[1].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
axes[0].set_xlabel("round", fontsize=13)
axes[0].set_ylabel("logical failure probability", fontsize=13)
axes[0].set_ylim(0,)
axes[1].set_xlabel("round", fontsize=13)
axes[1].set_ylabel("logical failure probability", fontsize=13)
axes[2].set_xlabel("round", fontsize=13)
axes[2].set_ylabel("N2/p_X^L", fontsize=13)
# axes.spines["top"].set_linewidth(2)
# axes.spines["left"].set_linewidth(2)
# axes.spines["bottom"].set_linewidth(2)
# axes.spines["right"].set_linewidth(2)
axes[0].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[0].set_title("X error", fontsize=14)
axes[1].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[1].set_title("X error(log-log)", fontsize=14)
axes[1].set_xscale("log")
axes[1].set_yscale("log")
axes[2].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[2].set_title("X lifetime", fontsize=14)
plt.legend()
plt.show()


fig, axes = plt.subplots(1,3,figsize=(18,6))
for i in range(len(code_distance_list)):
    b = np.array(data2.loc[code_distance_list[i]])
    axes[0].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[1].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
axes[0].set_xlabel("round", fontsize=13)
axes[0].set_ylabel("logical failure probability", fontsize=13)
axes[0].set_ylim(0,)
axes[1].set_xlabel("round", fontsize=13)
axes[1].set_ylabel("logical failure probability", fontsize=13)
axes[2].set_xlabel("round", fontsize=13)
axes[2].set_ylabel("N2/p_Z^L", fontsize=13)
# axes.spines["top"].set_linewidth(2)
# axes.spines["left"].set_linewidth(2)
# axes.spines["bottom"].set_linewidth(2)
# axes.spines["right"].set_linewidth(2)
axes[0].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[0].set_title("Z error", fontsize=14)
axes[1].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[1].set_title("Z error(log-log)", fontsize=14)
axes[1].set_xscale("log")
axes[1].set_yscale("log")
axes[2].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[2].set_title("Z lifetime", fontsize=14)
plt.legend()
plt.show()
# Out:
# /var/folders/z2/d7v_26mx7_s1sc2tvt5zxxmc0000gn/T/ipykernel_80889/2304731939.py:40: RuntimeWarning: divide by zero encountered in true_divide
#   axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
# /var/folders/z2/d7v_26mx7_s1sc2tvt5zxxmc0000gn/T/ipykernel_80889/2304731939.py:40: RuntimeWarning: divide by zero encountered in true_divide
#   axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
# /var/folders/z2/d7v_26mx7_s1sc2tvt5zxxmc0000gn/T/ipykernel_80889/2304731939.py:69: RuntimeWarning: divide by zero encountered in true_divide
#   axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
# /var/folders/z2/d7v_26mx7_s1sc2tvt5zxxmc0000gn/T/ipykernel_80889/2304731939.py:69: RuntimeWarning: divide by zero encountered in true_divide
#   axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
# /var/folders/z2/d7v_26mx7_s1sc2tvt5zxxmc0000gn/T/ipykernel_80889/2304731939.py:69: RuntimeWarning: divide by zero encountered in true_divide
#   axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
# /var/folders/z2/d7v_26mx7_s1sc2tvt5zxxmc0000gn/T/ipykernel_80889/2304731939.py:69: RuntimeWarning: divide by zero encountered in true_divide
#   axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import os

################ 要変更 #################

# FUjii-labのパス
path = "/Users/konohideki/Documents/Fujii-lab/surface_realistic/realistic_single_round/d1=7,p=0.0001,eta=1000"

# ファイル名
file1 = "X,p=0.0001,d2=(3,9,2),eta=1000,trials=20000" + ".csv"
file2 = "Z,p=0.0001,d2=(3,9,2),eta=1000,trials=20000" + ".csv"
########################################

# csvファイルの読み込み
os.chdir(path)
data1 = pd.read_csv(file1, index_col=0)
data2 = pd.read_csv(file2, index_col=0)

# データフレームの行名(リスト)を取得
code_distance_list = data1.index

# データフレームの列名(リスト)を取得
round_list = data1.columns

##### グラフ作成 #####

a = np.array(round_list)
a = [float(num) for num in a]
a = np.array(a)

fig, axes = plt.subplots(1,3,figsize=(18,6))
for i in range(len(code_distance_list)):
    b = np.array(data1.loc[code_distance_list[i]])
    axes[0].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[1].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
axes[0].set_xlabel("round", fontsize=13)
axes[0].set_ylabel("logical failure probability", fontsize=13)
axes[0].set_ylim(0,)
axes[1].set_xlabel("round", fontsize=13)
axes[1].set_ylabel("logical failure probability", fontsize=13)
axes[2].set_xlabel("round", fontsize=13)
axes[2].set_ylabel("N2/p_Z^L", fontsize=13)
# axes.spines["top"].set_linewidth(2)
# axes.spines["left"].set_linewidth(2)
# axes.spines["bottom"].set_linewidth(2)
# axes.spines["right"].set_linewidth(2)
axes[0].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[0].set_title("Z error", fontsize=14)
axes[1].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[1].set_title("Z error(log-log)", fontsize=14)
axes[1].set_xscale("log")
axes[1].set_yscale("log")
axes[2].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[2].set_title("Z lifetime", fontsize=14)
plt.legend()
plt.show()


fig, axes = plt.subplots(1,3,figsize=(18,6))
for i in range(len(code_distance_list)):
    b = np.array(data2.loc[code_distance_list[i]])
    axes[0].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[1].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
axes[0].set_xlabel("round", fontsize=13)
axes[0].set_ylabel("logical failure probability", fontsize=13)
axes[0].set_ylim(0,)
axes[1].set_xlabel("round", fontsize=13)
axes[1].set_ylabel("logical failure probability", fontsize=13)
axes[2].set_xlabel("round", fontsize=13)
axes[2].set_ylabel("N2/p_X^L", fontsize=13)
# axes.spines["top"].set_linewidth(2)
# axes.spines["left"].set_linewidth(2)
# axes.spines["bottom"].set_linewidth(2)
# axes.spines["right"].set_linewidth(2)
axes[0].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[0].set_title("X error", fontsize=14)
axes[1].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[1].set_title("X error(log-log)", fontsize=14)
axes[1].set_xscale("log")
axes[1].set_yscale("log")
axes[2].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[2].set_title("X lifetime", fontsize=14)
plt.legend()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import os

################ 要変更 #################

# FUjii-labのパス
path = "/Users/konohideki/Documents/Fujii-lab/surface_realistic/realistic_single_round/d1=9,p=0.0001,eta=1000"

# ファイル名
file1 = "X,p=0.0001,d2=(3,9,2),eta=1000,trials=20000" + ".csv"
file2 = "Z,p=0.0001,d2=(3,9,2),eta=1000,trials=20000" + ".csv"
########################################

# csvファイルの読み込み
os.chdir(path)
data1 = pd.read_csv(file1, index_col=0)
data2 = pd.read_csv(file2, index_col=0)

# データフレームの行名(リスト)を取得
code_distance_list = data1.index

# データフレームの列名(リスト)を取得
round_list = data1.columns

##### グラフ作成 #####

a = np.array(round_list)
a = [float(num) for num in a]
a = np.array(a)

fig, axes = plt.subplots(1,3,figsize=(18,6))
for i in range(len(code_distance_list)):
    b = np.array(data1.loc[code_distance_list[i]])
    axes[0].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[1].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
axes[0].set_xlabel("round", fontsize=13)
axes[0].set_ylabel("logical failure probability", fontsize=13)
axes[0].set_ylim(0,)
axes[1].set_xlabel("round", fontsize=13)
axes[1].set_ylabel("logical failure probability", fontsize=13)
axes[2].set_xlabel("round", fontsize=13)
axes[2].set_ylabel("N2/p_Z^L", fontsize=13)
# axes.spines["top"].set_linewidth(2)
# axes.spines["left"].set_linewidth(2)
# axes.spines["bottom"].set_linewidth(2)
# axes.spines["right"].set_linewidth(2)
axes[0].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[0].set_title("Z error", fontsize=14)
axes[1].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[1].set_title("Z error(log-log)", fontsize=14)
axes[1].set_xscale("log")
axes[1].set_yscale("log")
axes[2].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[2].set_title("Z lifetime", fontsize=14)
plt.legend()
plt.show()


fig, axes = plt.subplots(1,3,figsize=(18,6))
for i in range(len(code_distance_list)):
    b = np.array(data2.loc[code_distance_list[i]])
    axes[0].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[1].plot(a[0:], b[0:],marker='v',label="d2="+str(code_distance_list[i]))
    axes[2].plot(a[0:], a[0:]/b[0:],marker='v',label="d2="+str(code_distance_list[i]))
axes[0].set_xlabel("round", fontsize=13)
axes[0].set_ylabel("logical failure probability", fontsize=13)
axes[0].set_ylim(0,)
axes[1].set_xlabel("round", fontsize=13)
axes[1].set_ylabel("logical failure probability", fontsize=13)
axes[2].set_xlabel("round", fontsize=13)
axes[2].set_ylabel("N2/p_X^L", fontsize=13)
# axes.spines["top"].set_linewidth(2)
# axes.spines["left"].set_linewidth(2)
# axes.spines["bottom"].set_linewidth(2)
# axes.spines["right"].set_linewidth(2)
axes[0].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[0].set_title("X error", fontsize=14)
axes[1].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[1].set_title("X error(log-log)", fontsize=14)
axes[1].set_xscale("log")
axes[1].set_yscale("log")
axes[2].tick_params(direction="in", width=2, length=4, labelsize=12)
axes[2].set_title("X lifetime", fontsize=14)
plt.legend()
plt.show()

# %%
while i < 100:
    if i < 3:
        continue
        print(3)
    if i == 3:
        print(3)
        break
# Out:
# 3
