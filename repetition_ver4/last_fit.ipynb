# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import os

plt.rcParams["xtick.direction"] = "in"     
plt.rcParams["ytick.direction"] = "in" 
fig, ax = plt.subplots()
p_list = np.array([5e-04, 6e-04, 7e-04, 8e-04, 9e-04, 1e-03])
pL_matlix = np.array([])
pL_matlix = np.append(pL_matlix, np.array([[1.8274478212215573e-05, 2.865996025757119e-06, 6.606887802729425e-08, 6.523005618646685e-10]]))
pL_matlix = np.append(pL_matlix, np.array([[2.6213470783822538e-05, 4.497648751055074e-06, 1.1629633677469415e-07, 1.9615624220551198e-08]]))
pL_matlix = np.append(pL_matlix, np.array([[3.5495212555080977e-05, 5.699858829799709e-06, 1.7998946126970616e-07, 1.8543986249191305e-08]]))
pL_matlix = np.append(pL_matlix, np.array([[4.581650902554739e-05, 7.402621451189129e-06, 2.413533485133231e-07, 1.6447301300164824e-08]]))
pL_matlix = np.append(pL_matlix, np.array([[5.735459580974791e-05, 9.354538947258216e-06, 3.2219356877568686e-07, 1.3791503411722677e-08]]))
pL_matlix = np.append(pL_matlix, np.array([[7.086141202600107e-05, 1.1546729521826707e-05, 4.589012825028218e-07, 4.1933673649145386e-08]]))
pL_matlix = pL_matlix.reshape(6, 4)

a = np.array(p_list)
ax.plot(p_list, pL_matlix.T[0],marker='v',label="d="+str(3))
ax.plot(p_list, pL_matlix.T[1],marker='v',label="d="+str(5))
ax.plot(p_list, pL_matlix.T[2],marker='v',label="d="+str(7))
ax.plot(p_list, pL_matlix.T[3],marker='v',label="d="+str(9))
ax.set_xticklabels(np.round(a,decimals= 1))
ax.set_xticks(np.round(a,decimals= 2))
ax.set_xlabel("physical error probability", fontsize=13)
ax.set_ylabel("logical failure probability", fontsize=13)
#ax.set_ylim(10**(-3))
#ax.set_xlim(10**(-10))
ax.spines["top"].set_linewidth(2)
ax.spines["left"].set_linewidth(2)
ax.spines["bottom"].set_linewidth(2)
ax.spines["right"].set_linewidth(2)
ax.tick_params(direction="in", width=2, length=4, labelsize=12)
#ax.set_title("pm=" + str(0) + "%, eta=" + str(1000) + ", repeat=" + str(1) + ", trials=" + str(10000), fontsize=14)
#ax.set_xscale("log")
#ax.set_yscale("log")
ax.grid()
plt.legend()
plt.show()
# Out:
# [[1.82744782e-05 2.86599603e-06 6.60688780e-08 6.52300562e-10]
#  [2.62134708e-05 4.49764875e-06 1.16296337e-07 1.96156242e-08]
#  [3.54952126e-05 5.69985883e-06 1.79989461e-07 1.85439862e-08]
#  [4.58165090e-05 7.40262145e-06 2.41353349e-07 1.64473013e-08]
#  [5.73545958e-05 9.35453895e-06 3.22193569e-07 1.37915034e-08]
#  [7.08614120e-05 1.15467295e-05 4.58901283e-07 4.19336736e-08]]
# /var/folders/z2/d7v_26mx7_s1sc2tvt5zxxmc0000gn/T/ipykernel_3008/161127104.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.round(a,decimals= 1))

# %%
e_3_mean = np.mean(np.log10(pL_matlix.T[0])-2*np.log10(p_list))
e_5_mean = np.mean(np.log10(pL_matlix.T[1])-3*np.log10(p_list))
e_7_mean = np.mean(np.log10(pL_matlix.T[2])-4*np.log10(p_list))
e_9_mean = np.mean(np.log10(pL_matlix.T[3])-5*np.log10(p_list))
print(e_3_mean)
fig, ax = plt.subplots()
ax.plot(np.log10(p_list), np.log10(pL_matlix.T[0]),marker='v',label="d="+str(3))
ax.plot(np.log10(p_list), 2*np.log10(p_list)+e_3_mean,marker='',color='k',label="d="+str(3),linestyle="dashed")
ax.plot(np.log10(p_list), np.log10(pL_matlix.T[1]),marker='v',label="d="+str(5))
ax.plot(np.log10(p_list), 3*np.log10(p_list)+e_5_mean,marker='',color='k',label="d="+str(5),linestyle="dashed")
ax.plot(np.log10(p_list), np.log10(pL_matlix.T[2]),marker='v',label="d="+str(7))
ax.plot(np.log10(p_list), 4*np.log10(p_list)+e_7_mean,marker='',color='k',label="d="+str(7),linestyle="dashed")
ax.plot(np.log10(p_list), np.log10(pL_matlix.T[3]),marker='v',label="d="+str(9))
ax.plot(np.log10(p_list), 5*np.log10(p_list)+e_9_mean,marker='',color='k',label="d="+str(9),linestyle="dashed")
ax.spines["top"].set_linewidth(2)
ax.spines["left"].set_linewidth(2)
ax.spines["bottom"].set_linewidth(2)
ax.spines["right"].set_linewidth(2)
ax.tick_params(direction="in", width=2, length=4, labelsize=12)
#ax.set_title("pm=" + str(0) + "%, eta=" + str(1000) + ", repeat=" + str(1) + ", trials=" + str(10000), fontsize=14)
ax.grid()
plt.legend()
plt.show()
# Out:
# 1.8569059554150609
