# %%
ep_list_3 = [1.4857289093445743e-05, 2.16439610616432e-05, 2.9126673615760934e-05, 3.740654972501743e-05, 4.726077776940056e-05, 5.905581672298666e-05]
ep_list_5 = [3.947493632861567e-06, 5.641516669930808e-06, 7.662422628634914e-06, 1.0531015970994832e-05, 1.312612356201594e-05, 1.6499140484116008e-05]
ep_list_7 = [9.094999584921432e-07, 1.3010050672088465e-06, 1.823582532210523e-06, 2.4467176847978843e-06, 3.2713157827044826e-06, 4.050126255665121e-06]
ep_list_9 = [4.9283723889138876e-08, 1.0236495907381925e-07, 1.49971696845847e-07, 2.3611151434986143e-07, 3.149715846068516e-07, 4.5647819769769214e-07]
p_list = [0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.001]

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import os

plt.rcParams["xtick.direction"] = "in"     
plt.rcParams["ytick.direction"] = "in" 
fig, ax = plt.subplots()
p_list = np.array([5e-04, 6e-04, 7e-04, 8e-04, 9e-04, 1e-03])
e_3 = np.array([1.4857289093445743e-05, 2.16439610616432e-05, 2.9126673615760934e-05, 3.740654972501743e-05, 4.726077776940056e-05, 5.905581672298666e-05])
e_5 = np.array([3.947493632861567e-06, 5.641516669930808e-06, 7.662422628634914e-06, 1.0531015970994832e-05, 1.312612356201594e-05, 1.6499140484116008e-05])
e_7 = np.array([9.094999584921432e-07, 1.3010050672088465e-06, 1.823582532210523e-06, 2.4467176847978843e-06, 3.2713157827044826e-06, 4.050126255665121e-06])
e_9 = np.array([4.9283723889138876e-08, 1.0236495907381925e-07, 1.49971696845847e-07, 2.3611151434986143e-07, 3.149715846068516e-07, 4.5647819769769214e-07])

a = np.array(p_list)
ax.plot(p_list, e_3,marker='v',label="d="+str(3))
ax.plot(p_list, e_5,marker='v',label="d="+str(5))
ax.plot(p_list, e_7,marker='v',label="d="+str(7))
ax.plot(p_list, e_9,marker='v',label="d="+str(9))
ax.set_xticklabels(np.round(a,decimals= 1))
ax.set_xticks(np.round(a,decimals= 2))
ax.set_xlabel("physical error probability", fontsize=13)
ax.set_ylabel("logical failure probability", fontsize=13)
#ax.set_ylim(10**(-3))
#ax.set_xlim(10**(-10))
ax.spines["top"].set_linewidth(2)
ax.spines["left"].set_linewidth(2)
ax.spines["bottom"].set_linewidth(2)
ax.spines["right"].set_linewidth(2)
ax.tick_params(direction="in", width=2, length=4, labelsize=12)
#ax.set_title("pm=" + str(0) + "%, eta=" + str(1000) + ", repeat=" + str(1) + ", trials=" + str(10000), fontsize=14)
#ax.set_xscale("log")
#ax.set_yscale("log")
ax.grid()
plt.legend()
plt.show()
# Out:
# /var/folders/z2/d7v_26mx7_s1sc2tvt5zxxmc0000gn/T/ipykernel_82065/4163090150.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.round(a,decimals= 1))

# %%
e_3_mean = np.mean(np.log10(e_3)-2*np.log10(p_list))
e_5_mean = np.mean(np.log10(e_5)-7/3*np.log10(p_list))
e_7_mean = np.mean(np.log10(e_7)-8/3*np.log10(p_list))
e_9_mean = np.mean(np.log10(e_9)-3*np.log10(p_list))
print(e_3_mean)
fig, ax = plt.subplots()
ax.plot(np.log10(p_list), np.log10(e_3),marker='v',label="d="+str(3))
ax.plot(np.log10(p_list), 2*np.log10(p_list)+e_3_mean,marker='',color='k',label="d="+str(3),linestyle="dashed")
ax.plot(np.log10(p_list), np.log10(e_5),marker='v',label="d="+str(5))
ax.plot(np.log10(p_list), 7/3*np.log10(p_list)+e_5_mean,marker='',color='k',label="d="+str(5),linestyle="dashed")
ax.plot(np.log10(p_list), np.log10(e_7),marker='v',label="d="+str(7))
ax.plot(np.log10(p_list), 8/3*np.log10(p_list)+e_7_mean,marker='',color='k',label="d="+str(7),linestyle="dashed")
ax.plot(np.log10(p_list), np.log10(e_9),marker='v',label="d="+str(9))
ax.plot(np.log10(p_list), 3*np.log10(p_list)+e_9_mean,marker='',color='k',label="d="+str(9),linestyle="dashed")
ax.spines["top"].set_linewidth(2)
ax.spines["left"].set_linewidth(2)
ax.spines["bottom"].set_linewidth(2)
ax.spines["right"].set_linewidth(2)
ax.tick_params(direction="in", width=2, length=4, labelsize=12)
#ax.set_title("pm=" + str(0) + "%, eta=" + str(1000) + ", repeat=" + str(1) + ", trials=" + str(10000), fontsize=14)
ax.grid()
plt.legend()
plt.show()
# Out:
# 1.7718624702246861
