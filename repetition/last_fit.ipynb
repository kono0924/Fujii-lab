# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import os

plt.rcParams["xtick.direction"] = "in"     
plt.rcParams["ytick.direction"] = "in" 
fig, ax = plt.subplots()
p_list = np.array([5e-04, 6e-04, 7e-04, 8e-04, 9e-04, 1e-03])
pL_matlix = np.array([])
pL_matlix = np.append(pL_matlix, np.array([[8.034795429245955e-06, 9.526259166802203e-07, 3.564360648244737e-08, -6.875118362973233e-18]]))
pL_matlix = np.append(pL_matlix, np.array([[1.1493925395648677e-05, 1.4351364398702088e-06, 5.8008269591050156e-08, -6.875118362973233e-18]]))
pL_matlix = np.append(pL_matlix, np.array([[1.5834019273916438e-05, 2.041625567713862e-06, 9.085645311443252e-08, 7.687830378922536e-09]]))
pL_matlix = np.append(pL_matlix, np.array([[2.0724622623908445e-05, 2.8760184747406528e-06, 1.323245869852894e-07, 4.426326452057999e-09]]))
pL_matlix = np.append(pL_matlix, np.array([[2.6456921743186723e-05, 3.964465409885648e-06, 2.1293088450851916e-07, 1.6307522617992836e-08]]))
pL_matlix = np.append(pL_matlix, np.array([[3.250604950568665e-05, 4.942540980231827e-06, 3.2825058623555796e-07, 2.9353546429527135e-08]]))
pL_matlix = pL_matlix.reshape(6, 4)

a = np.array(p_list)
ax.plot(p_list, pL_matlix.T[0],marker='v',label="d="+str(3))
ax.plot(p_list, pL_matlix.T[1],marker='v',label="d="+str(5))
ax.plot(p_list, pL_matlix.T[2],marker='v',label="d="+str(7))
ax.plot(p_list, pL_matlix.T[3],marker='v',label="d="+str(9))
ax.set_xticklabels(np.round(a,decimals= 1))
ax.set_xticks(np.round(a,decimals= 2))
ax.set_xlabel("physical error probability", fontsize=13)
ax.set_ylabel("logical failure probability", fontsize=13)
#ax.set_ylim(10**(-3))
#ax.set_xlim(10**(-10))
ax.spines["top"].set_linewidth(2)
ax.spines["left"].set_linewidth(2)
ax.spines["bottom"].set_linewidth(2)
ax.spines["right"].set_linewidth(2)
ax.tick_params(direction="in", width=2, length=4, labelsize=12)
#ax.set_title("pm=" + str(0) + "%, eta=" + str(1000) + ", repeat=" + str(1) + ", trials=" + str(10000), fontsize=14)
#ax.set_xscale("log")
#ax.set_yscale("log")
ax.grid()
plt.legend()
plt.show()
# Out:
# /var/folders/z2/d7v_26mx7_s1sc2tvt5zxxmc0000gn/T/ipykernel_3008/4149878981.py:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(np.round(a,decimals= 1))

# %%
e_3_mean = np.mean(np.log10(pL_matlix.T[0])-2*np.log10(p_list))
e_5_mean = np.mean(np.log10(pL_matlix.T[1])-3*np.log10(p_list))
e_7_mean = np.mean(np.log10(pL_matlix.T[2])-4*np.log10(p_list))
e_9_mean = np.mean(np.log10(pL_matlix.T[3])-5*np.log10(p_list))
print(e_3_mean)
fig, ax = plt.subplots()
ax.plot(np.log10(p_list), np.log10(pL_matlix.T[0]),marker='v',label="d="+str(3))
ax.plot(np.log10(p_list), 2*np.log10(p_list)+e_3_mean,marker='',color='k',label="d="+str(3),linestyle="dashed")
ax.plot(np.log10(p_list), np.log10(pL_matlix.T[1]),marker='v',label="d="+str(5))
ax.plot(np.log10(p_list), 3*np.log10(p_list)+e_5_mean,marker='',color='k',label="d="+str(5),linestyle="dashed")
ax.plot(np.log10(p_list), np.log10(pL_matlix.T[2]),marker='v',label="d="+str(7))
ax.plot(np.log10(p_list), 4*np.log10(p_list)+e_7_mean,marker='',color='k',label="d="+str(7),linestyle="dashed")
ax.plot(np.log10(p_list), np.log10(pL_matlix.T[3]),marker='v',label="d="+str(9))
ax.plot(np.log10(p_list), 5*np.log10(p_list)+e_9_mean,marker='',color='k',label="d="+str(9),linestyle="dashed")
ax.spines["top"].set_linewidth(2)
ax.spines["left"].set_linewidth(2)
ax.spines["bottom"].set_linewidth(2)
ax.spines["right"].set_linewidth(2)
ax.tick_params(direction="in", width=2, length=4, labelsize=12)
#ax.set_title("pm=" + str(0) + "%, eta=" + str(1000) + ", repeat=" + str(1) + ", trials=" + str(10000), fontsize=14)
ax.grid()
plt.legend()
plt.show()
# Out:
# 1.5094868201704947
# /var/folders/z2/d7v_26mx7_s1sc2tvt5zxxmc0000gn/T/ipykernel_3008/414338075.py:4: RuntimeWarning: invalid value encountered in log10
#   e_9_mean = np.mean(np.log10(pL_matlix.T[3])-5*np.log10(p_list))
# /var/folders/z2/d7v_26mx7_s1sc2tvt5zxxmc0000gn/T/ipykernel_3008/414338075.py:13: RuntimeWarning: invalid value encountered in log10
#   ax.plot(np.log10(p_list), np.log10(pL_matlix.T[3]),marker='v',label="d="+str(9))

# %%
p_sta = 0.0005
p_fin = 0.001
p_div = 0.0001
p_list= np.arange(p_sta,p_fin+p_div,p_div)

# %%
print(p_list)
print(p_list[4])
# Out:
# [0.0005 0.0006 0.0007 0.0008 0.0009 0.001 ]
# 0.0009000000000000002
